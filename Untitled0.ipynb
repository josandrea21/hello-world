# %% [markdown]
# <a href="https://colab.research.google.com/github/josandrea21/hello-world/blob/master/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#siurve para trabajar con un dataframe
import pandas as pd
#llamada pandas pero presentado como pd
import matplotlib.pyplot as m

# %%
#filas y columnas
dicc = {"a":[4,85,55],"b":[55,3,565]}
dicc
# Out:
# {'a': [4, 85, 55], 'b': [55, 3, 565]}

# %%
df = pd.DataFrame(dicc)
df
# Out:
#     a    b
# 0   4   55
# 1  85    3
# 2  55  565

# %%
a = open("earthquakes.csv","r")
b = a.read()
b

# segunda manera de leer un archivo
import pandas
df = pd.read_csv("https://raw.githubusercontent.com/ryali93/UNMSM_programacion/master/data/earthquakes.csv")
type(df)
df
# Out:
#                     DateTime  Latitude  Longitude  ...   RMS  Source       EventID
# 0     2002/01/01 10:39:06.82  -55.2140  -129.0000  ...  1.07     NEI  2.002010e+11
# 1     2002/01/01 11:29:22.73    6.3030   125.6500  ...  0.90     NEI  2.002010e+11
# 2     2002/01/02 14:50:33.49  -17.9830   178.7440  ...  1.08     NEI  2.002010e+11
# 3     2002/01/02 17:22:48.76  -17.6000   167.8560  ...  0.90     NEI  2.002010e+11
# 4     2002/01/03 07:05:27.67   36.0880    70.6870  ...  0.87     NEI  2.002010e+11
# 5     2002/01/03 10:17:36.30  -17.6640   168.0040  ...  1.14     NEI  2.002010e+11
# 6     2002/01/10 11:14:56.93   -3.2120   142.4270  ...  1.18     NEI  2.002011e+11
# 7     2002/01/13 14:10:56.52   -5.6510   151.0740  ...  1.06     NEI  2.002011e+11
# 8     2002/01/15 04:47:59.85  -17.3340   167.7220  ...  1.09     NEI  2.002012e+11
# 9     2002/01/15 07:12:58.03   -6.3140   105.2050  ...  1.23     NEI  2.002012e+11
# ...

# %%
# primera manera de obtener datos del archivo
df["Magnitude"]
# segunda manera de obtener datos del archivo
df.Magnitude

# %%
df[df.Magnitude > 7]
len(df[df.Magnitude > 7])
# Out:
# 199

# %%
df["Latitude"]
len(df[df.Latitude < 0])
# Out:
# 1345

# %%
# y
df[(df.Magnitude > 7) & (df.Latitude < 0)]
# o
df[(df.Magnitude > 7) | (df.Latitude < 0)]

# %%
#terremotosen peru aprox.
d = df[(df["Latitude"].between(-18,0)) & (df["Longitude"].between(-82,-69))]
d[d["Magnitude"] == max(d["Magnitude"])]
# Out:
#                    DateTime  Latitude  Longitude  ...   RMS  Source       EventID
# 867  2007/08/15 23:40:57.89   -13.386    -76.603  ...  0.86     NEI  2.007082e+11
#
# [1 rows x 12 columns]
